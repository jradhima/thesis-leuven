# %%
import pandas as pd
import sqlite3
import re
#import torch.nn.functional as f
#import torch

from transformers import BertForSequenceClassification, BertTokenizer
from transformers import pipeline

finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone',num_labels=3)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')

nlp = pipeline("sentiment-analysis", model=finbert, tokenizer=tokenizer)

# %%
con = sqlite3.connect('data.db')

cur = con.cursor()

articles = [*cur.execute("select * from article;")]

con.close()

# %%
articles = pd.DataFrame(articles, columns=['idx', 'title', 'text', 'href', 'date']).set_index('idx')

articles['text_size'] = articles['text'].apply(lambda x: len(x.split()))

articles['date'] = pd.to_datetime(articles['date'], infer_datetime_format=True)

mask = articles['date'] >= '2020-01-01'
articles = articles[mask]

mask = articles['date'] < '2021-01-01'
articles = articles[mask]

mask = articles['text_size'] > 50
articles = articles[mask]
mask = articles['text_size'] < 300
articles = articles[mask]

articles['text_size'].hist(bins=50, figsize=(15,5));

# %%
title_sentiment = []
text_sentiment = []
i = 0
for row in articles.itertuples():
    i += 1
    if i % 100 == 0:
        print(i)
    sentiment = nlp([row.title, row.text])
    title_sentiment.append(sentiment[0])
    text_sentiment.append(sentiment[1])
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
articles['title_sentiment'] = title_sentiment
articles['text_sentiment'] = text_sentiment
articles.to_json('HKUSTsentiment.json')

# %%
articles.head()
# Out:
#                                                   title  \
# idx
# 1496  Brown-Forman stock slips after profit misses o...
# 1498  This analysis of Wall Street stock ratings is ...
# 1499  These 74 stocks in the S&P 500 hit all-time re...
# 1500  Brown-Forman's stock slips, although earnings ...
# 1502  Brown-Forman's stock gains after sales beat, a...
#
#                                                    text  \
# idx
# 1496  Shares of Jack Daniels parent Brown-Forman Cor...
# 1498  In the financial media, “Wall Street” typicall...
# 1499  U.S. stocks staged a broad rally Wednesday as ...
# 1500  Shares of Jack Daniel's parent Brown-Forman Co...
# 1502  Shares of Brown-Forman Corp. BF.A,\n+0.38%\ned...
#
#                                                    href       date  text_size  \
# idx
# 1496  https://www.marketwatch.com/story/brown-forman... 2020-12-08        153
# 1498  https://www.marketwatch.com/story/this-analysi... 2020-09-07        272
# ...

# %%
articles['title_sentiment'] = articles['title_sentiment'].apply(lambda x: x['score'] if x['label']=='positive' else
                                                                           -x['score'] if x['label']=='negative' else 0)
articles['text_sentiment'] = articles['text_sentiment'].apply(lambda x: x['score'] if x['label']=='positive' else
                                                                           -x['score'] if x['label']=='negative' else 0)

articles.head()
# Out:
#                                                   title  \
# idx
# 1496  Brown-Forman stock slips after profit misses o...
# 1498  This analysis of Wall Street stock ratings is ...
# 1499  These 74 stocks in the S&P 500 hit all-time re...
# 1500  Brown-Forman's stock slips, although earnings ...
# 1502  Brown-Forman's stock gains after sales beat, a...
#
#                                                    text  \
# idx
# 1496  Shares of Jack Daniels parent Brown-Forman Cor...
# 1498  In the financial media, “Wall Street” typicall...
# 1499  U.S. stocks staged a broad rally Wednesday as ...
# 1500  Shares of Jack Daniel's parent Brown-Forman Co...
# 1502  Shares of Brown-Forman Corp. BF.A,\n+0.38%\ned...
#
#                                                    href       date  text_size  \
# idx
# 1496  https://www.marketwatch.com/story/brown-forman... 2020-12-08        153
# 1498  https://www.marketwatch.com/story/this-analysi... 2020-09-07        272
# ...

# %%
articles.drop(columns=['temp_sentiment'], inplace=True)
articles.head()
# Out:
#                                                   title  \
# idx
# 1496  Brown-Forman stock slips after profit misses o...
# 1498  This analysis of Wall Street stock ratings is ...
# 1499  These 74 stocks in the S&P 500 hit all-time re...
# 1500  Brown-Forman's stock slips, although earnings ...
# 1502  Brown-Forman's stock gains after sales beat, a...
#
#                                                    text  \
# idx
# 1496  Shares of Jack Daniels parent Brown-Forman Cor...
# 1498  In the financial media, “Wall Street” typicall...
# 1499  U.S. stocks staged a broad rally Wednesday as ...
# 1500  Shares of Jack Daniel's parent Brown-Forman Co...
# 1502  Shares of Brown-Forman Corp. BF.A,\n+0.38%\ned...
#
#                                                    href       date  text_size  \
# idx
# 1496  https://www.marketwatch.com/story/brown-forman... 2020-12-08        153
# 1498  https://www.marketwatch.com/story/this-analysi... 2020-09-07        272
# ...

# %%
articles.to_json('HKUSTsentiment.json')

# %%
tokenizer = BertTokenizer.from_pretrained('ProsusAI/finbert')
finbert = BertForSequenceClassification.from_pretrained('ProsusAI/finbert')
nlp = pipeline("sentiment-analysis", model=finbert, tokenizer=tokenizer)

# %%
title_sentiment = []
text_sentiment = []
i = 0
for row in articles.itertuples():
    i += 1
    if i % 100 == 0:
        print(i)
    sentiment = nlp([row.title, row.text])
    title_sentiment.append(sentiment[0])
    text_sentiment.append(sentiment[1])
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
articles['title_sentiment'] = title_sentiment
articles['text_sentiment'] = text_sentiment

articles['title_sentiment'] = articles['title_sentiment'].apply(lambda x: x['score'] if x['label']=='positive' else
                                                                           -x['score'] if x['label']=='negative' else 0)
articles['text_sentiment'] = articles['text_sentiment'].apply(lambda x: x['score'] if x['label']=='positive' else
                                                                           -x['score'] if x['label']=='negative' else 0)

articles.to_json('PROSUSsentiment.json')

# %%
articles.head()
# Out:
#                                                   title  \
# idx
# 1496  Brown-Forman stock slips after profit misses o...
# 1498  This analysis of Wall Street stock ratings is ...
# 1499  These 74 stocks in the S&P 500 hit all-time re...
# 1500  Brown-Forman's stock slips, although earnings ...
# 1502  Brown-Forman's stock gains after sales beat, a...
#
#                                                    text  \
# idx
# 1496  Shares of Jack Daniels parent Brown-Forman Cor...
# 1498  In the financial media, “Wall Street” typicall...
# 1499  U.S. stocks staged a broad rally Wednesday as ...
# 1500  Shares of Jack Daniel's parent Brown-Forman Co...
# 1502  Shares of Brown-Forman Corp. BF.A,\n+0.38%\ned...
#
#                                                    href       date  text_size  \
# idx
# 1496  https://www.marketwatch.com/story/brown-forman... 2020-12-08        153
# 1498  https://www.marketwatch.com/story/this-analysi... 2020-09-07        272
# ...
